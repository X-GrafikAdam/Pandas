# %% [markdown]
# ## Data

# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col="Column")

# %%
df.rename(columns={"ConvertedComp":"Salary"}, inplace=True) # convertedcomp ı salary ile değiştir verinde ...inplace ile güncelle.

# %% [markdown]
# ## Aggregation

# %% [markdown]
# Combining multiple pieces of data into a single result
#
# * For example mean and median are aggregate functions, they take data and convert them into a single result

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.head(50)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df["Salary"].head(50)
# Out:
# Respondent
# 1           NaN
# 2           NaN
# 3        8820.0
# 4       61000.0
# 5           NaN
# 6      366420.0
# 7           NaN
# 8           NaN
# 9       95179.0
# 10      13293.0
# 11          NaN
# 12          NaN
# 13      90000.0
# 14      57060.0
# 15          NaN
# 16     455352.0
# 17      65277.0
# 18      21996.0
# 19      31140.0
# 20      41244.0
# 21          NaN
# 22     103000.0
# 23      69000.0
# 24      26388.0
# 25       6300.0
# 26     114000.0
# 27          NaN
# 28          NaN
# 29     100000.0
# 30      90417.0
# 31          NaN
# 32    1100000.0
# 33       8400.0
# 34          NaN
# 35      80000.0
# 36      20628.0
# 37          NaN
# 38      51312.0
# 39     156000.0
# 40          NaN
# 41          NaN
# 42          NaN
# 43      20623.0
# 44      87996.0
# 45     175000.0
# 46          NaN
# 47     187000.0
# 48          NaN
# 49      60000.0
# 50       5597.0
# Name: Salary, dtype: float64

# %% [markdown]
# ### Mean

# %%
df["Salary"].mean()
# Out:
# 127110.73842323056

# %% [markdown]
# ### Median

# %%
df["Salary"].median()
# Out:
# 57287.0

# %% [markdown]
# ### Describe

# %%
df.describe()# sayılar sütünların istatiksel bilgilerini verir.
                #countta dolu olanları veriyor. Kaç tane değer verilmiş.
                #% 25.... %100  minimumu 0 oalrak düşün maksimumu % 100 olarak düşün.% 50 si benim medyanım olur. 
                # % 25 i minimumla % 50 arasının medyanı olmuş oluyor.
                #Orta üstü orta altı olarak adlandırıyoruz.
# Out:
#           CompTotal        Salary   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %% [markdown]
# `describe` metodunu aynı zamanda `Series` objeleri ile de kullanabiliriz

# %%
df["Salary"].describe() #salary ın describenıda inceleyebilirim.
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: Salary, dtype: float64

# %% [markdown]
# ### Count

# %% [markdown]
# * NA olmayan değerleri sayar

# %%
df["Salary"].count() #kaç tane veri dolu onu bana verir.
# Out:
# 55823

# %%
len(df) #33 bin kişi salarye cevap vermemiş. 88 bin - 55 bin kişi gibi düşün.
# Out:
# 88883

# %%
df.count()
# Out:
# MainBranch      88331
# Hobbyist        88883
# OpenSourcer     88883
# OpenSource      86842
# Employment      87181
#                 ...
# Sexuality       76147
# Ethnicity       76668
# Dependents      83059
# SurveyLength    86984
# SurveyEase      87081
# Length: 84, dtype: int64

# %% [markdown]
# ### value_counts

# %%
df["Hobbyist"].value_counts()#eşşiz değerlerden kaç tane var onu gösterir.
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
# value_counts Series objeleri için
df.value_counts()
# Out:
# MainBranch                                                                     Hobbyist  OpenSourcer                                         OpenSource                                                                       Employment          Country        Student         EdLevel                                                 UndergradMajor                                                         EduOther                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  OrgSize                   DevType           
# ...

# %%
df["SocialMedia"].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df["SocialMedia"].value_counts()["Reddit"]
# Out:
# 14374

# %%
df["SocialMedia"].value_counts().loc["Reddit"]
# Out:
# 14374

# %% [markdown]
# **Değerdese yüzde olarak değeri istiyorsak:**

# %%
df["SocialMedia"].value_counts(normalize=True) #normalize true ile bunu sağlarız.
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %% [markdown]
# * Diyelim ki farklı ülkelerdeki sosyal medya trendini incelemek istiyorum. Bunu kolayca yapabileceğimiz `groupby` mantığına bakacağız bir sonraki derste.

# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])

# %%
a.sum()
# Out:
# 15

# %%
(a / a.sum())
# Out:
# array([0.06666667, 0.13333333, 0.2       , 0.26666667, 0.33333333])
